# %% [markdown]
# # Extract driving time and driving distance between locations
#
# In this notebook, we extract the driving time and distance between locations, as determined by NYC taxi drivers.

# %%
import pandas as pd

# %%
df = pd.read_csv("../taxi-data/rides_testing.csv", index_col=0)

# %%
df.groupby(['pos','dropoff_pos']).mean()
# Out:
#                                       trip_time_in_secs  trip_distance  \
# pos                  dropoff_pos
# ('-0.00', '0.00')    (-73.99, 40.74)              780.0          2.240
# ('-0.00', '40.74')   (-73.98, 40.75)              720.0          2.200
# ('-0.00', '40.80')   (-73.96, 40.79)              600.0          1.610
# ('-0.00', '73.99')   (-0.04, 40.74)               300.0          1.530
# ('-0.00', '74.00')   (-73.96, 40.74)             1380.0          4.320
# ('-0.01', '0.01')    (-0.01, 0.01)                690.0          2.080
# ('-0.01', '40.72')   (-73.98, 40.77)              900.0          3.760
# ('-0.02', '0.00')    (-73.87, 40.77)             1500.0         15.820
#                      (-73.95, 40.77)              360.0          0.970
#                      (-73.96, 40.78)              300.0          1.180
#                      (-73.97, 40.76)             1560.0          6.610
#                      (-73.97, 40.79)              420.0          0.760
# ...
